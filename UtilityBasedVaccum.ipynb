# %% [markdown]
# <a href="https://colab.research.google.com/github/recursivesn/AI-Lab3-Sushant-Neupane/blob/main/UtilityBasedVaccum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

ROWS = 8
COLS = 8

class Environment:
    def __init__(self):
        self.grid = [['dirty' if random.random() < 0.3 else 'clean' for _ in range(COLS)] for _ in range(ROWS)]

    def is_dirty(self, x, y):
        return self.grid[x][y] == 'dirty'

    def clean(self, x, y):
        self.grid[x][y] = 'clean'

    def display(self):
        for row in self.grid:
            print(" | ".join(row))
        print()

    def any_dirty_left(self):
        return any('dirty' in row for row in self.grid)


class UtilityBasedVacuumAgent:
    def __init__(self, env):
        self.env = env
        self.x = 0
        self.y = 0

    def utility(self, x, y):
        """Higher utility for dirty tiles that are closer."""
        distance = abs(self.x - x) + abs(self.y - y)
        if self.env.is_dirty(x, y):
            return 100 - distance  # prioritize dirty tiles closer to agent
        return -1  # no utility for clean tiles

    def find_best_tile(self):
        best_score = -1
        best_pos = None
        for i in range(ROWS):
            for j in range(COLS):
                score = self.utility(i, j)
                if score > best_score:
                    best_score = score
                    best_pos = (i, j)
        return best_pos

    def move_to(self, x, y):
        print(f"Moving from ({self.x},{self.y}) to ({x},{y})")
        self.x = x
        self.y = y

    def clean(self):
        if self.env.is_dirty(self.x, self.y):
            print(f"Cleaning ({self.x},{self.y})")
            self.env.clean(self.x, self.y)
        else:
            print(f"({self.x},{self.y}) already clean.")

    def run(self):
        while self.env.any_dirty_left():
            target = self.find_best_tile()
            if target:
                self.move_to(*target)
                self.clean()
            else:
                break


env = Environment()
agent = UtilityBasedVacuumAgent(env)

print("Initial Environment:")
env.display()

agent.run()

print("Final Environment:")
env.display()
# Out:
# Initial Environment:
# clean | dirty | clean | clean | clean | dirty | clean | clean
# clean | clean | clean | dirty | dirty | dirty | clean | dirty
# dirty | clean | dirty | clean | dirty | dirty | dirty | clean
# clean | clean | dirty | dirty | clean | dirty | clean | clean
# clean | clean | clean | clean | clean | dirty | dirty | clean
# clean | dirty | clean | clean | dirty | clean | clean | clean
# dirty | clean | clean | clean | dirty | clean | dirty | clean
# dirty | dirty | clean | clean | dirty | clean | dirty | clean
#
# Moving from (0,0) to (0,1)
# Cleaning (0,1)
# Moving from (0,1) to (1,3)
# Cleaning (1,3)
# Moving from (1,3) to (1,4)
# Cleaning (1,4)
# Moving from (1,4) to (1,5)
# Cleaning (1,5)
# Moving from (1,5) to (0,5)
# Cleaning (0,5)
# Moving from (0,5) to (2,5)
# Cleaning (2,5)
# Moving from (2,5) to (2,4)
# Cleaning (2,4)
# Moving from (2,4) to (2,2)
# Cleaning (2,2)
# Moving from (2,2) to (3,2)
# Cleaning (3,2)
# Moving from (3,2) to (3,3)
# Cleaning (3,3)
# Moving from (3,3) to (3,5)
# Cleaning (3,5)
# Moving from (3,5) to (4,5)
# Cleaning (4,5)
# Moving from (4,5) to (4,6)
# Cleaning (4,6)
# Moving from (4,6) to (2,6)
# Cleaning (2,6)
# Moving from (2,6) to (1,7)
# Cleaning (1,7)
# Moving from (1,7) to (6,6)
# Cleaning (6,6)
# Moving from (6,6) to (7,6)
# Cleaning (7,6)
# Moving from (7,6) to (7,4)
# Cleaning (7,4)
# Moving from (7,4) to (6,4)
# Cleaning (6,4)
# Moving from (6,4) to (5,4)
# Cleaning (5,4)
# Moving from (5,4) to (5,1)
# Cleaning (5,1)
# Moving from (5,1) to (6,0)
# Cleaning (6,0)
# Moving from (6,0) to (7,0)
# Cleaning (7,0)
# Moving from (7,0) to (7,1)
# Cleaning (7,1)
# Moving from (7,1) to (2,0)
# Cleaning (2,0)
# Final Environment:
# clean | clean | clean | clean | clean | clean | clean | clean
# clean | clean | clean | clean | clean | clean | clean | clean
# clean | clean | clean | clean | clean | clean | clean | clean
# clean | clean | clean | clean | clean | clean | clean | clean
# clean | clean | clean | clean | clean | clean | clean | clean
# clean | clean | clean | clean | clean | clean | clean | clean
# clean | clean | clean | clean | clean | clean | clean | clean
# clean | clean | clean | clean | clean | clean | clean | clean
